# %% [markdown]
# # Kapitel 1 – Einführung in R
#
# ## Lernziele
#
# Nach diesem Notebook kannst du:
#
# - einfache Berechnungen durchführen
# - Variablen erstellen
# - mit Objekten arbeiten
# - eigene Aufgaben lösen

# %% [markdown]
# ## Erste Berechnungen
#
# R kann als Taschenrechner verwendet werden.

# %%
2 + 2

# %% [markdown]
# ## Variablen erstellen
#
# Syntax:
#
# `name <- wert`

# %%
x <- 10
x

# %% [markdown]
# ## Variablen verwenden

# %%
y <- 5
x + y

# %% [markdown]
# # Aufgaben
#
# ## Aufgabe 1
#
# Erstelle eine Variable namens `a` mit Wert 100.

# %%
# Deine Lösung hier

# %% [markdown]
# ## Aufgabe 2
#
# Erstelle zwei Variablen und addiere sie.

# %%
# Deine Lösung hier

# %% [markdown]
# ---
#
# ## Zusammenfassung
#
# Du hast gelernt:
#
# - Berechnungen
# - Variablen
# - Arbeiten mit R in Jupyter
#
# Gut gemacht!
