# %% [markdown]
# # Kapitel 2
#
# ## Lernziele
# - Verständnis zentraler Konzepte
# - Praktische Anwendung in R

# %%
2 + 2

# %% [markdown]
# ## Übung
# Erstelle eigene Variablen und führe eine Berechnung durch.

# %%
# Deine Lösung hier
